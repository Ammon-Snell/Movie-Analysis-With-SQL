# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
import pandas as pd
import numpy as np

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9747423 entries, 0 to 9747422
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 669.3+ MB

# %%
basics = basics.replace({'\\N':np.nan})

# %%
basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9747418  tt9916848  tvEpisode              Episode #3.17
# 9747419  tt9916850  tvEpisode              Episode #3.19
# 9747420  tt9916852  tvEpisode              Episode #3.20
# 9747421  tt9916856      short                   The Wind
# 9747422  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# ...

# %%
basics.dropna(subset=['runtimeMinutes', 'genres'], inplace = True)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
moviefilter = basics['titleType']=='movie'

# %%
basics = basics[moviefilter]

# %%
basics
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9747189  tt9916362     movie
# 9747273  tt9916538     movie
# 9747314  tt9916622     movie
# 9747341  tt9916680     movie
# 9747373  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9747189                                              Coven
# 9747273                                Kuambil Lagi Hatiku
# 9747314        Rodolpho Teóphilo - O Legado de um Pioneiro
# ...

# %%
basics['startYear'].value_counts()
# Out:
# 2017    14366
# 2018    14309
# 2019    14036
# 2016    13940
# 2015    13459
#         ...
# 1904        1
# 1897        1
# 1896        1
# 2026        1
# 1894        1
# Name: startYear, Length: 130, dtype: int64

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 380222 entries, 8 to 9747373
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          380222 non-null  object
#  1   titleType       380222 non-null  object
#  2   primaryTitle    380222 non-null  object
#  3   originalTitle   380222 non-null  object
#  4   isAdult         380222 non-null  object
#  5   startYear       373813 non-null  object
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  380222 non-null  object
#  8   genres          380222 non-null  object
# dtypes: object(9)
# memory usage: 29.0+ MB

# %%
data_types_dict = {'startYear': float}

# %%
basics = basics.astype(data_types_dict)

# %%
startyear = basics['startYear']>=2000
basics = basics[startyear]

# %%
startyear = basics['startYear']<=2022
basics = basics[startyear]

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)

# %%
basics = basics[~is_documentary]

# %%
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34803  tt0035423     movie                                     Kate & Leopold
# 61116  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67669  tt0069049     movie                         The Other Side of the Wind
# 77964  tt0079644     movie                                      November 1828
# 86801  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult  startYear endYear  \
# 34803                             Kate & Leopold       0     2001.0     NaN
# 61116  El tango del viudo y su espejo deformante       0     2020.0     NaN
# 67669                 The Other Side of the Wind       0     2018.0     NaN
# 77964                              November 1828       0     2001.0     NaN
# 86801                          The Naked Monster       0     2005.0     NaN
#
# ...

# %%
akas = akas.replace({'\\N':np.nan})

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35481321 entries, 0 to 35481320
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ GB

# %%
moviefilter = akas['region']=='US'

# %%
akas = akas[moviefilter]
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35480847  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35480917  tt9916620         1                          The Copeland Case
# 35481006  tt9916702         1              Loving London: The Playground
# 35481049  tt9916756         1                   Pretty Pretty Black Girl
# 35481065  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# ...

# %%
ratings = ratings.replace({'\\N':np.nan})

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34803       True
# 61116       True
# 67669       True
# 77964      False
# 86801       True
#            ...
# 9747096     True
# 9747105     True
# 9747144    False
# 9747189     True
# 9747273    False
# Name: tconst, Length: 147162, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9746561  tt9914942     movie
# 9746956  tt9915872     movie
# 9747096  tt9916170     movie
# 9747105  tt9916190     movie
# 9747189  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9746561                             Life Without Sara Amat
# 9746956                               The Last White Witch
# 9747096                                      The Rehearsal
# ...

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =ratings['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1297078    False
# 1297079    False
# 1297080    False
# 1297081    False
# 1297082    False
# Name: tconst, Length: 1297083, dtype: bool

# %%
ratings = ratings[keepers]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1965
# 1        tt0000002            5.8       262
# 4        tt0000005            6.2      2603
# 5        tt0000006            5.1       178
# 6        tt0000007            5.4       816
# ...            ...            ...       ...
# 1297047  tt9916200            8.1       227
# 1297048  tt9916204            8.2       260
# 1297055  tt9916348            8.3        18
# 1297056  tt9916362            6.4      5260
# 1297060  tt9916428            3.8        14
#
# [494484 rows x 3 columns]

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['.ipynb_checkpoints',
#  'results_in_progress_CO_pizza.json',
#  'results_in_progress_CO_vegan.json',
#  'superhero_info - superhero_info.csv',
#  'superhero_powers - superhero_powers.csv',
#  'title.akas.tsv.gz',
#  'title.basics.tsv.gz',
#  'title.ratings.tsv.gz']

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1965
# 1  tt0000002            5.8       262
# 2  tt0000005            6.2      2603
# 3  tt0000006            5.1       178
# 4  tt0000007            5.4       816
